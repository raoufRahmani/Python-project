# %% [markdown]
# # Projet Python

# %%
from dataclasses import dataclass
import numpy as np
import pandas as pd
from sklearn import datasets
import statsmodels.api as sm

# %% [markdown]
# ## 1)Dataset

# %%
@dataclass
class Dataset:
    X : np.ndarray
    Y : np.ndarray
    features_names : list
    n : int
    p : int
    

def add_intercept(vecteur_1 :np.ndarray, K : np.ndarray):
        M = np.column_stack([vecteur_1, K])
        return M



def to_dataframe(A : np.ndarray, B : np.ndarray, noms : list):
        df = pd.DataFrame(A, columns=noms)
        df["variable_expliquée"] = B
        return df

    

T, V = datasets.make_regression(n_samples=1000, n_features=6, noise=10)


p = 6
feature_list = [f"X{i}" for i in range(p)]
feature_list.insert(0, "constante")


data_1 = Dataset(X=T, Y=V, features_names=feature_list, n=1000, p=6)



vecteur = np.ones((data_1.n, 1))
X_avec_constante = add_intercept(vecteur_1=vecteur, K=data_1.X)


df = to_dataframe(X_avec_constante, data_1.Y,feature_list)

# %%
df['variable_expliquée']
# Out:
#      constante        X0        X1        X2        X3        X4        X5  \
# 0          1.0 -1.997537 -2.403168  0.440159  1.132758 -0.197942 -2.235136
# 1          1.0 -1.983746  0.085624 -1.720682 -1.782035 -0.139605 -1.111159
# 2          1.0 -0.322394  0.691901  1.078247 -0.484650 -1.457296  1.690907
# 3          1.0  0.520353 -1.115978 -0.260971 -1.408121 -0.012379  1.031847
# 4          1.0 -0.714625 -0.124101 -0.893683  0.911655  1.839231 -0.154971
# ..         ...       ...       ...       ...       ...       ...       ...
# 995        1.0  2.758243  0.355835 -0.397826 -2.140945 -2.066058 -0.483907
# 996        1.0  0.181287 -0.799322  1.035936  1.682648 -0.280007  0.524628
# 997        1.0 -1.333748 -1.994147 -1.517330  2.225133  0.130131  0.544746
# 998        1.0 -0.954252 -2.178520 -0.330055  0.432666  0.564950  0.776367
# 999        1.0 -0.364260 -0.002578 -0.362128  1.086056  0.864890  1.996840
#
#      variable_expliquée
# 0           -216.487543
# 1           -164.025388
# 2             60.561083
# 3           -113.061113
# 4             45.025859
# ..                  ...
# 995          -63.111704
# 996           42.559155
# 997          -82.587974
# 998         -130.276123
# 999           93.949652
#
# [1000 rows x 8 columns]

# %% [markdown]
# ## Regression Linéaire

# %%
@dataclass
class regression_lineaire : 
    coefficients : np.ndarray 
    features_names : list 






def regression(data)-> regression_lineaire :
    X_df=pd.DataFrame(X_avec_constante)
    Y_df=pd.DataFrame(data.Y)
    model=sm.OLS(Y_df,X_df)
    results = model.fit()
    return results 
    


resultats_regression=  regression(data_1)

# remplire la dataclass

res_regression=regression_lineaire(coefficients=resultats_regression.params, features_names=feature_list)

# Dictionnaire
dict_coeff={feature_list[i] : resultats_regression.params[i] for i in range(len((feature_list))) }

# %% [markdown]
# ### Dictionnaire

# %%
print(dict_coeff)
# Out:
# {'constante': np.float64(0.14558598415508417), 'X0': np.float64(21.44282878805125), 'X1': np.float64(68.1516919047287), 'X2': np.float64(16.63191750202442), 'X3': np.float64(37.55549634578159), 'X4': np.float64(19.03071065220101), 'X5': np.float64(21.24506173768206)}

# %% [markdown]
# ### régression linéaire

# %%
res_regression
# Out:
# regression_lineaire(coefficients=0     0.145586
# 1    21.442829
# 2    68.151692
# 3    16.631918
# 4    37.555496
# 5    19.030711
# 6    21.245062
# dtype: float64, features_names=['constante', 'X0', 'X1', 'X2', 'X3', 'X4', 'X5'])

# %% [markdown]
# ### Inférance

# %%
resultats_regression.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      0   R-squared:                       0.987
# Model:                            OLS   Adj. R-squared:                  0.987
# Method:                 Least Squares   F-statistic:                 1.299e+04
# Date:                Thu, 20 Nov 2025   Prob (F-statistic):               0.00
# Time:                        14:19:01   Log-Likelihood:                -3718.9
# No. Observations:                1000   AIC:                             7452.
# Df Residuals:                     993   BIC:                             7486.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 0              0.1456      0.319      0.457      0.648      -0.480       0.771
# 1             21.4428      0.319     67.248      0.000      20.817      22.069
# 2             68.1517      0.303    224.863      0.000      67.557      68.746
# 3             16.6319      0.309     53.844      0.000      16.026      17.238
# 4             37.5555      0.316    118.964      0.000      36.936      38.175
# 5             19.0307      0.324     58.708      0.000      18.395      19.667
# 6             21.2451      0.325     65.278      0.000      20.606      21.884
# ==============================================================================
# Omnibus:                        1.004   Durbin-Watson:                   1.900
# Prob(Omnibus):                  0.605   Jarque-Bera (JB):                0.894
# Skew:                           0.065   Prob(JB):                        0.640
# Kurtosis:                       3.067   Cond. No.                         1.18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
results, my_dict, reg_lineaire = linear_regression(data_1)
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      0   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                 4.333e+04
# Date:                Wed, 19 Nov 2025   Prob (F-statistic):               0.00
# Time:                        23:44:35   Log-Likelihood:                -3726.1
# No. Observations:                1000   AIC:                             7466.
# Df Residuals:                     993   BIC:                             7501.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 0              0.4346      0.319      1.361      0.174      -0.192       1.061
# 1             90.0446      0.309    291.663      0.000      89.439      90.650
# 2             34.1170      0.320    106.698      0.000      33.490      34.744
# 3             31.9664      0.304    105.115      0.000      31.370      32.563
# 4             88.5461      0.312    284.207      0.000      87.935      89.157
# 5             68.7230      0.312    220.049      0.000      68.110      69.336
# 6             50.5481      0.315    160.560      0.000      49.930      51.166
# ==============================================================================
# Omnibus:                        2.682   Durbin-Watson:                   2.069
# Prob(Omnibus):                  0.262   Jarque-Bera (JB):                2.564
# Skew:                          -0.094   Prob(JB):                        0.278
# Kurtosis:                       3.162   Cond. No.                         1.12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
@dataclass
class Dataset:
    X : np.ndarray
    Y : np.ndarray
    features_names : list
    n : int
    p : int
    
    def add_intercept (self):
        self.X = np.column_stack((np.ones(self.n), self.X))
        self.features_names = ["Intercept"] + self.features_names
        return self.X


    def to_dataframe(self):
        df = pd.DataFrame(self.X, columns= self.features_names)
        df["variable_expliquée"] = self.Y
        return df
    

T, V = datasets.make_regression(n_samples=1000, n_features=6, noise=10)

# %%
@dataclass
class regression_lineaire:
    coefficients: np.ndarray
    features_names: list


def linear_regression(data) -> regression_lineaire:
    X_df = pd.DataFrame(X_avec_constante)
    Y_df = pd.DataFrame(data.Y)
    model = sm.OLS(Y_df, X_df)
    results = model.fit()
    return results

results =linear_regression(data_1)
my_dict = {feature_list[i]: results.params[i] for i in range(len(feature_list))}
